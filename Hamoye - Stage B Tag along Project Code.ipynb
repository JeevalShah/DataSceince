# %%
import pandas as pd
import numpy as np
import seaborn as sns

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, r2_score, mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Ridge, Lasso

# %% [markdown]
# # EDA

# %%
energy_df = pd.read_csv("./Downloads/energydata_complete.csv")
energy_df
# Out:
#                       date  Appliances  lights         T1       RH_1  \
# 0      2016-01-11 17:00:00          60      30  19.890000  47.596667
# 1      2016-01-11 17:10:00          60      30  19.890000  46.693333
# 2      2016-01-11 17:20:00          50      30  19.890000  46.300000
# 3      2016-01-11 17:30:00          50      40  19.890000  46.066667
# 4      2016-01-11 17:40:00          60      40  19.890000  46.333333
# ...                    ...         ...     ...        ...        ...
# 19730  2016-05-27 17:20:00         100       0  25.566667  46.560000
# 19731  2016-05-27 17:30:00          90       0  25.500000  46.500000
# 19732  2016-05-27 17:40:00         270      10  25.500000  46.596667
# 19733  2016-05-27 17:50:00         420      10  25.500000  46.990000
# 19734  2016-05-27 18:00:00         430      10  25.500000  46.600000
#
#               T2       RH_2         T3       RH_3         T4  ...         T9  \
# ...

# %%
energy_df.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
# ...

# %%
energy_df.tail()
# Out:
#                       date  Appliances  lights         T1       RH_1  \
# 19730  2016-05-27 17:20:00         100       0  25.566667  46.560000
# 19731  2016-05-27 17:30:00          90       0  25.500000  46.500000
# 19732  2016-05-27 17:40:00         270      10  25.500000  46.596667
# 19733  2016-05-27 17:50:00         420      10  25.500000  46.990000
# 19734  2016-05-27 18:00:00         430      10  25.500000  46.600000
#
#               T2       RH_2         T3       RH_3    T4  ...    T9     RH_9  \
# 19730  25.890000  42.025714  27.200000  41.163333  24.7  ...  23.2  46.7900
# 19731  25.754000  42.080000  27.133333  41.223333  24.7  ...  23.2  46.7900
# 19732  25.628571  42.768571  27.050000  41.690000  24.7  ...  23.2  46.7900
# 19733  25.414000  43.036000  26.890000  41.290000  24.7  ...  23.2  46.8175
# 19734  25.264286  42.971429  26.823333  41.156667  24.7  ...  23.2  46.8450
#
#            T_out  Press_mm_hg     RH_out  Windspeed  Visibility  Tdewpoint  \
# ...

# %%
energy_df.shape
# Out:
# (19735, 29)

# %%
energy_df.describe()
# Out:
#          Appliances        lights            T1          RH_1            T2  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      97.694958      3.801875     21.686571     40.259739     20.341219
# std      102.524891      7.935988      1.606066      3.979299      2.192974
# min       10.000000      0.000000     16.790000     27.023333     16.100000
# 25%       50.000000      0.000000     20.760000     37.333333     18.790000
# 50%       60.000000      0.000000     21.600000     39.656667     20.000000
# 75%      100.000000      0.000000     22.600000     43.066667     21.500000
# max     1080.000000     70.000000     26.260000     63.360000     29.856667
#
#                RH_2            T3          RH_3            T4          RH_4  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      40.420420     22.267611     39.242500     20.855335     39.026904
# ...

# %%
energy_df.dtypes
# Out:
# date            object
# Appliances       int64
# lights           int64
# T1             float64
# RH_1           float64
# T2             float64
# RH_2           float64
# T3             float64
# RH_3           float64
# T4             float64
# RH_4           float64
# T5             float64
# RH_5           float64
# T6             float64
# RH_6           float64
# T7             float64
# RH_7           float64
# T8             float64
# RH_8           float64
# T9             float64
# RH_9           float64
# T_out          float64
# Press_mm_hg    float64
# RH_out         float64
# Windspeed      float64
# Visibility     float64
# Tdewpoint      float64
# rv1            float64
# rv2            float64
# dtype: object

# %%
energy_df.nunique()
# Out:
# date           19735
# Appliances        92
# lights             8
# T1               722
# RH_1            2547
# T2              1650
# RH_2            3376
# T3              1426
# RH_3            2618
# T4              1390
# RH_4            2987
# T5              2263
# RH_5            7571
# T6              4446
# RH_6            9709
# T7              1955
# RH_7            5891
# T8              2228
# RH_8            6649
# T9               924
# RH_9            3388
# T_out           1730
# Press_mm_hg     2189
# RH_out           566
# Windspeed        189
# Visibility       413
# Tdewpoint       1409
# rv1            19735
# rv2            19735
# dtype: int64

# %%
energy_df.columns
# Out:
# Index(['date', 'Appliances', 'lights', 'T1', 'RH_1', 'T2', 'RH_2', 'T3',
#        'RH_3', 'T4', 'RH_4', 'T5', 'RH_5', 'T6', 'RH_6', 'T7', 'RH_7', 'T8',
#        'RH_8', 'T9', 'RH_9', 'T_out', 'Press_mm_hg', 'RH_out', 'Windspeed',
#        'Visibility', 'Tdewpoint', 'rv1', 'rv2'],
#       dtype='object')

# %%
missing_values = pd.DataFrame({'Count':energy_df.isna().sum(),'Percentage':energy_df.isna().sum()/len(energy_df)*100})
missing_values
# Out:
#              Count  Percentage
# date             0         0.0
# Appliances       0         0.0
# lights           0         0.0
# T1               0         0.0
# RH_1             0         0.0
# T2               0         0.0
# RH_2             0         0.0
# T3               0         0.0
# RH_3             0         0.0
# T4               0         0.0
# RH_4             0         0.0
# T5               0         0.0
# RH_5             0         0.0
# T6               0         0.0
# RH_6             0         0.0
# T7               0         0.0
# RH_7             0         0.0
# T8               0         0.0
# RH_8             0         0.0
# T9               0         0.0
# RH_9             0         0.0
# T_out            0         0.0
# Press_mm_hg      0         0.0
# RH_out           0         0.0
# Windspeed        0         0.0
# Visibility       0         0.0
# Tdewpoint        0         0.0
# rv1              0         0.0
# rv2              0         0.0

# %% [markdown]
# ## Q17
# From the dataset, fit a linear model on the relationship between the temperature in the living room in Celsius (x = T2) and the temperature outside the building (y = T6). What is the Root Mean Squared error in three D.P?

# %%
x = energy_df["T2"]
y = energy_df["T6"]

# %%
arr = np.array(x)
x_feature = arr.reshape(-1, 1)

# %%
x_train, x_test, y_train, y_test = train_test_split(x_feature, y, train_size=0.7, test_size = 0.3, random_state=42)

#Defining & Fitting the model
linear_model = LinearRegression()
linear_model.fit(x_train, y_train)

#Making predictions with the model
predictions = linear_m.predict(x_test)

# %%
rmse = np.sqrt(mean_squared_error(y_test, predictions))
print("Root Mean Squared Error (MAE) for the testing set:", round(rmse, 3))
# Out:
# Root Mean Squared Error (MAE) for the testing set: 3.63

# %% [markdown]
# ## Q18
# Remove the following columns: [“date”, “lights”]. The target variable is “Appliances”. Use a 70-30 train-test set split with a  random state of 42 (for reproducibility). Normalize the dataset using the MinMaxScaler (Hint: Use the MinMaxScaler fit_transform and transform methods on the train and test set respectively). Run a multiple linear regression using the training set. Answer the following questions:
#
# What is the Mean Absolute Error (in three decimal places) for the  training set?

# %%
new_energy_df = energy_df.drop(columns=["date", "lights"])
new_energy_df.head()
# Out:
#    Appliances     T1       RH_1    T2       RH_2     T3       RH_3         T4  \
# 0          60  19.89  47.596667  19.2  44.790000  19.79  44.730000  19.000000
# 1          60  19.89  46.693333  19.2  44.722500  19.79  44.790000  19.000000
# 2          50  19.89  46.300000  19.2  44.626667  19.79  44.933333  18.926667
# 3          50  19.89  46.066667  19.2  44.590000  19.79  45.000000  18.890000
# 4          60  19.89  46.333333  19.2  44.530000  19.79  45.000000  18.890000
#
#         RH_4         T5  ...         T9   RH_9     T_out  Press_mm_hg  RH_out  \
# 0  45.566667  17.166667  ...  17.033333  45.53  6.600000        733.5    92.0
# 1  45.992500  17.166667  ...  17.066667  45.56  6.483333        733.6    92.0
# 2  45.890000  17.166667  ...  17.000000  45.50  6.366667        733.7    92.0
# 3  45.723333  17.166667  ...  17.000000  45.40  6.250000        733.8    92.0
# 4  45.530000  17.200000  ...  17.000000  45.40  6.133333        733.9    92.0
#
# ...

# %%
# Define predictor (x) and target (y)
x = new_energy_df.drop(columns=["Appliances"])
y = new_energy_df["Appliances"]

# %%
# Split data into train and test sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# Scale the values
scaler = MinMaxScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
# Training the linear regression model
model = LinearRegression()
model.fit(x_train_scaled, y_train)

# Predictions on the training set
train_predictions = model.predict(x_train_scaled)

# %%
# Calculate Mean Absolute Error (MAE) for the training set
train_mae = mean_absolute_error(y_train, train_predictions)
print("Mean Absolute Error (MAE) for the training set:", round(train_mae, 3))
# Out:
# Mean Absolute Error (MAE) for the training set: 53.742

# %% [markdown]
# ## Q19
# What is the Root Mean Squared Error (in three decimal places) for the training set?

# %%
# Calculate Root Mean Squared Error (RMSE) for the training set
train_rmse = np.sqrt(mean_squared_error(y_train, train_predictions))
print("Root Mean Squared Error (RMSE) for the training set:", round(train_rmse, 3))
# Out:
# Root Mean Squared Error (RMSE) for the training set: 95.216

# %% [markdown]
# ## Q20
# What is the Mean Absolute Error (in three decimal places) for test set?

# %%
# Predictions on the test set
test_predictions = model.predict(x_test_scaled)

# Calculate Mean Absolute Error (MAE) for the test set
test_mae = mean_absolute_error(y_test, test_predictions)
print("Mean Absolute Error (MAE) for the test set:", round(test_mae, 3))
# Out:
# Mean Absolute Error (MAE) for the test set: 53.643

# %% [markdown]
# ## Q21
# What is the Root Mean Squared Error (in three decimal places) for test set?

# %%
# Calculate Root Mean Squared Error (RMSE) for the test set
test_rmse = np.sqrt(mean_squared_error(y_test, test_predictions))
print("Root Mean Squared Error (RMSE) for the test set:", round(test_rmse, 3))
# Out:
# Root Mean Squared Error (RMSE) for the test set: 93.64

# %% [markdown]
# ## Q22
# Did the Model above overfit to the training set

# %% [markdown]
# Ans. No, as RMSE & MAE values for both training & testing set are ~equal.

# %% [markdown]
# ## Q23
# Train a ridge regression model with default parameters. Is there any change to the root mean squared error (RMSE) when evaluated on the test set?

# %%
# Training a Ridge regression model
ridge_model = Ridge()
ridge_model.fit(x_train_scaled, y_train)

# Predictions on the test set
ridge_test_preds = ridge_model.predict(x_test_scaled)

# Calculating RMSE for the Ridge model on the test set
ridge_test_rmse = np.sqrt(mean_squared_error(y_test, ridge_test_preds))
print("RMSE for Ridge Regression on the test set:", round(ridge_test_rmse, 3))
# Out:
# RMSE for Ridge Regression on the test set: 93.709

# %%
if(round(ridge_test_rmse, 3) != round(test_rmse, 3)):
    print("Change in RMSE detected")
else:
    print("No Change in RMSE detected")
# Out:
# Change in RMSE detected

# %% [markdown]
# ## Q24
# Train a lasso regression model with default value and obtain the new feature weights with it. How many of the features have non-zero feature weights?

# %%
# Training a Lasso regression model with default parameters
lasso_model = Lasso()  # Default parameters
lasso_model.fit(x_train_scaled, y_train)

# Retrieving the coefficients (feature weights)
lasso_feature_weights = lasso_model.coef_

# Counting the number of features with non-zero feature weights
non_zero_features = sum(lasso_feature_weights != 0)

print("Number of features with non-zero feature weights:", non_zero_features)
# Out:
# Number of features with non-zero feature weights: 4

# %% [markdown]
# ## Q25
# What is the new RMSE with the Lasso Regression on the test set?

# %%
# Predict on the test set using the trained Lasso model
lasso_test_preds = lasso_model.predict(x_test_scaled)

# Calculate RMSE for the Lasso model on the test set
lasso_test_rmse = np.sqrt(mean_squared_error(y_test, lasso_test_preds))

print("RMSE for Lasso Regression on the test set:", round(lasso_test_rmse, 3))
# Out:
# RMSE for Lasso Regression on the test set: 99.424
